# %% [markdown]
# ### **Exploración Scrap Perfil de Docentes**

# %% [markdown]
# #### ***Load and transform data***

# %%
import pandas as pd 
from pathlib import Path

### Load Data
DATA_PATH = Path("../scripts/scrap_perfiles_docentes.csv")
perfiles = pd.read_csv(DATA_PATH)

### Transform Data ### 
perfiles.columns = perfiles.columns.str.lower()
perfiles['perfil'] = perfiles['perfil'].str.lower()

# %% [markdown]
# #### ***Utils***

# %%
def filter_profile_by_word(df:pd.DataFrame,word:str):
    """
    Función para filtrar registros por coincidencia de termino en el perfil del docente. 
    
    """
    NEGRITA = "\033[1m"
    RESET = "\033[0m"
    output_df = df[df['perfil'].str.contains(word)].reset_index(drop=True)
    print('Información de los docentes:\n')
    if output_df.empty == True:
        print('No hay conincidencias. :(')
    else:

        for row in range(len(output_df)):
            print(f'\n{NEGRITA}{output_df.loc[row,'nombre']} - {output_df.loc[row,'departamento']}{RESET}')
            print(f'{NEGRITA}Cargo:{RESET} {output_df.loc[row,'cargo']}')
            print(f'{NEGRITA}Formación academica:{RESET} {output_df.loc[row,'formacion_academica']}')
        
            print(f'{NEGRITA}Perfil:{RESET} {output_df.loc[row,'perfil']}')
            print(f'{NEGRITA}URL:{RESET} {output_df.loc[row,'url_perfil']}')

            print('----------'*10)
    return output_df

# %% [markdown]
# #### ***Exploring Data***

# %%
print('Docenter por Facultad: ')
display(perfiles['departamento'].value_counts().reset_index())
print(f"\n Numero total de docentes consultados: {len(perfiles)}")
# Out:
# Docenter por Facultad:
#              departamento  count
# 0   Ingeniería Industrial     29
# 1  Ingeniería de Sistemas     28
# 2  Ingeniería Electrónica     27
#  Numero total de docentes consultados: 84

# %% [markdown]
# #### ***Filtering Data***
#
# Vamos a buscar qué perfiles de todos los que se scrapearon contienen una determinada palabra; en este caso se hará con palabras relacionadas a la idea que tengo de proyecto de trabajo de grado.

# %%
results = filter_profile_by_word(df=perfiles,word='economía')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %%
results = filter_profile_by_word(df=perfiles,word='lenguaje natural')
# Out:
# Información de los docentes:
#
#
# Jorge Andrés Alvarado Valencia, Ph.D. - Ingeniería Industrial
# Cargo: Profesor Titular - Consejero Académico
# Formación academica: Doctorado, Doctor en Ingeniería | Fecha de grado: | 18 dic 2014 | Maestría, Master of Science in Analytics | Fecha de grado: | 01 may 2009 | Maestría, Magister en Educación | Fecha de grado: | 01 mar 2006 | Pregrado, Ingeniero Industrial | Fecha de grado: | 01 abr 1997
# Perfil: soy un profesor universitario e investigador en los campos del procesamiento de lenguaje natural, inteligencia artificial y analítica de datos para negocios con un enfoque en ciencias cognitivas y 13 años de experiencia en gestión universitaria. los logros y habilidades clave incluyen:
# desarrollar e implementar modelos analíticos y de inteligencia artificial útiles basados ​​en datos en un entorno altamente interdisciplinario.
# realizar investigaciones de vanguardia en el procesamiento del lenguaje natural (nlp) y ciencias cognitivas con un enfoque en los sentidos y las emociones, y la interacción humano-computadora con un enfoque en el pronóstico de la demanda con juicio humano.
# administrar equipos en universidades para cumplir con los objetivos académicos, presupuestales y educativos bajo restricciones de tiempo y recursos.
# tutoría y desarrollo de habilidades de personas en el campo de la ciencia de datos y la inteligencia artificial por medio de currículos formales y cursos de educación continua.
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/jorge.alvarado
# ----------------------------------------------------------------------------------------------------
#
# Alexandra Pomares Quimbaya, Ph.D. - Ingeniería de Sistemas
# Cargo: Profesor Titular
# Formación academica: Doctorado, Doctora en Ingenieria | Fecha de grado: | 25 sept 2010 | Doctorado, Doctorado en Informática | Fecha de grado: | 26 jul 2010 | Maestría, Magister en Ingenieria de Sistemas y Computacion | Fecha de grado: | 01 mar 2006 | Pregrado, Ingeniero de Sistemas | Fecha de grado: | 01 dic 1999
# Perfil: ing. alexandra pomares quimbaya, ph.d.
#  es directora de investigación y profesora titular en la pontificia universidad javeriana, en bogotá, colombia. a lo largo de su trayectoria ha trabajado en inteligencia de negocios, analítica e integración de datos en ámbitos académicos, de investigación y consultoría. actualmente se enfoca en fortalecer las capacidades de investigación en colombia y la región, y en el análisis de datos no estructurados mediante técnicas de procesamiento de lenguaje natural y algoritmos de aprendizaje automático.
# es presidenta del comité de cultura y desarrollo digital de la universidad, desde donde impulsa iniciativas institucionales para promover la toma de decisiones basada en datos y la adopción responsable de tecnologías digitales. sus intereses de investigación incluyen la inteligencia artificial y sus aplicaciones en la investigación, particularmente el uso de ia para mejorar los flujos de trabajo científicos, optimizar el análisis de información compleja y apoyar la generación de evidencia.
# ha sido investigadora visitante en la medical university of graz (austria), aalborg university (dinamarca) y la universidad de jaén (españa). es ingeniera de sistemas de la pontificia universidad javeriana, magíster en ingeniería de sistemas y computación de la universidad de los andes, doctora en ingeniería de la universidad de los andes (colombia) y doctora en ciencias de la computación de la universidad de grenoble (francia).
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/alexandra-pomares-quimbaya
# ----------------------------------------------------------------------------------------------------
#
# Andrés Dario Moreno Barbosa, Ph.D. - Ingeniería de Sistemas
# Cargo: Profesor Asistente - Consejero Académico
# Formación academica: Doctorado, Doctor en Informática | Fecha de grado: | 02 may 2016 | Doctorado, Doctor en Informática | Fecha de grado: | 02 may 2016 | Maestría, Maestría En Ingeniería De Sistemas Y Computación | Fecha de grado: | 20 sept 2008 | Pregrado, Ingeniero de Sistemas y Computación | Fecha de grado: | 16 sept 2006
# Perfil: andrés moreno es profesor del departamento de ingeniería de sistemas en la pontificia universidad javeriana (bogotá) e investigador en ciencia de datos aplicada e inteligencia artificial. su trabajo se centra en el diseño, implementación y evaluación de modelos de
# machine learning
# , aprendizaje profundo (
# deep learning
# ) y procesamiento de lenguaje natural (nlp), así como en el desarrollo de arquitecturas de datos a gran escala para aplicaciones de alto impacto social.
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/ad.morenob
# ----------------------------------------------------------------------------------------------------
#
# Jaime Andrés Pavlich Mariscal, Ph.D. - Ingeniería de Sistemas
# Cargo: Profesor Titular - Consejero Académico
# Formación academica: Doctorado, Doctor de Filosofía en Ciencias de la Computacion e Ingenieria | Fecha de grado: | 14 dic 2008 | Pregrado, Licenciado en Ciencias de la Ingeniería | Fecha de grado: | 28 ene 2000
# Perfil: jaime a. pavlich-mariscal es profesor titular de la pontificia universidad javeriana (colombia). sus áreas de interés son: ingeniería de software, software científico, análisis de datos y procesamiento del lenguaje natural. ha publicado varios artículos sobre dichos temas en conferencias y revistas. a lo largo de su carrera, ha desempeñado roles como desarrollador, arquitecto y consultor especializado en proyectos de ingeniería de software para diversas organizaciones, incluidas universidades, entidades gubernamentales y empresas del sector privado, tanto a nivel nacional como internacional.
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/jpavlich
# ----------------------------------------------------------------------------------------------------

# %%
results = filter_profile_by_word(df=perfiles,word='inversión')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %%
results = filter_profile_by_word(df=perfiles,word='inversiones')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %%
results = filter_profile_by_word(df=perfiles,word='banca')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %%
results = filter_profile_by_word(df=perfiles,word='banco')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %%
results = filter_profile_by_word(df=perfiles,word='mercado')
# Out:
# Información de los docentes:
#
#
# Eduardo Andrés Gerlein Reyes, Ph.D. - Ingeniería Electrónica
# Cargo: Profesor Asociado
# Formación academica: Doctorado, Doctor en Ciencias de la Computación | Fecha de grado: | 20 abr 2016 | Maestría, Maestria en Ingeniería Electrónica | Fecha de grado: | 01 sept 2008 | Pregrado, Ingeniero Electrónico | Fecha de grado: | 01 sept 2002
# Perfil: eduardo gerlein obtuvo su título de ingeniero en electrónica de la pontificia universidad javeriana (bogotá, colombia) en 2002 y su maestría en ciencias en ingeniería electrónica en 2008 de la misma institución. entre enero de 2003 y junio de 2005, se desempeñó como asistente de investigación en el departamento de ingeniería electrónica en la pontificia universidad javeriana, dentro del grupo de sistemas inteligentes, robótica y percepción. posteriormente, fue nombrado profesor instructor en el departamento de electrónica en la pontificia universidad javeriana.
# en el verano de 2009, gerlein fue seleccionado para una pasantía de investigación de verano en el departamento de ingeniería eléctrica y de computadoras en la universidad de delaware (newark, ee. uu.), bajo la supervisión del profesor sylvain cloutier, enfocándose en el desarrollo del curso de dispositivos semiconductores.
# en junio de 2016, recibió su doctorado de la universidad de ulster (irlanda del norte, reino unido), con base en el centro de investigación de sistemas inteligentes (londonderry, irlanda del norte) como parte del grupo de ingeniería de mercados de capitales. bajo la supervisión del profesor martin mcginnity, el dr. ammar belatreche y la dra. sonya coleman, su investigación estuvo dirigida al desarrollo de arquitecturas de hardware para sistemas multiagente en fpga para aplicaciones financieras.
# intereses de investigación: robótica, sistemas multiagente, sistemas embebidos, diseño de sistemas digitales, bioingeniería.
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/egerlein
# ----------------------------------------------------------------------------------------------------
#
# José Reinaldo Vuelvas Quintana, Ph.D. - Ingeniería Electrónica
# Cargo: Profesor Asistente
# Formación academica: Doctorado, Doctor en Ingeniería | Fecha de grado: | 16 mar 2019 | Maestría, Magíster en Ingeniería Electrónica | Fecha de grado: | 04 sept 2010 | Pregrado, Ingeniero Electrónico | Fecha de grado: | 08 sept 2009
# Perfil: ingeniero electrónico con maestría y doctorado en ingeniería, con énfasis en sistemas de control, mercados eléctricos y optimización. profesor asociado y director de la maestría en energía y sostenibilidad en la pontificia universidad javeriana (colombia), donde lidera el grupo de investigación cepit, reconocido en categoría a1 por minciencias. su trabajo de investigación, desarrollado a lo largo de más de una década, se centra en la respuesta a la demanda, los vehículos eléctricos, la teoría de juegos aplicada a mercados eléctricos, y los sistemas de gestión de energía para microrredes. ha publicado extensamente en revistas de alto impacto como applied energy, ieee access y sustainable energy, grids & networks, y ha sido reconocido como investigador senior por minciencias. cuenta con experiencia en dirección de tesis doctorales, gestión académica de posgrado, consultoría energética con el sector productivo, y formación continua para empresas del sector energético.
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/vuelvasj
# ----------------------------------------------------------------------------------------------------
#
# Clara Mabel Solano Vanegas, Ph.D. - Ingeniería Industrial
# Cargo: Profesor Asociado - Consejero Académico
# Formación academica: Doctorado, Doctora en Ingeniería | Fecha de grado: | 10 mar 2018 | Maestría, Magistra en Educación | Fecha de grado: | 13 mar 2009 | Especialización, Especialista en Mercadeo | Fecha de grado: | 01 nov 2001 | Pregrado, Ingeniero Industrial | Fecha de grado: | 01 oct 1992
# Perfil: la ingeniera clara mabel solano vanegas se encuentra vinculada a la pontificia universidad javeriana como profesora asociada del departamento de ingeniería industrial.  actualmente se desempeña como jefe de la sección de gestión del departamento.  en docencia es responsable de las asignaturas  ingeniería de mercados, práctica social proyecto cdio-3, en el pregrado del programa de ingeniería industrial, y a nivel de posgrado, en la maestría de ingeniería industrial, en la asignatura de seminario ii.
# los temas de interés y por ende, de investigación son: investigación de mercados, cadenas de suministro humanitarias y mejoramiento de procesos.
# URL: https://perfilesycapacidades.javeriana.edu.co/es/persons/solano.c
# ----------------------------------------------------------------------------------------------------

# %%
results = filter_profile_by_word(df=perfiles,word='finanzas')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %%
results = filter_profile_by_word(df=perfiles,word='indicadores')
# Out:
# Información de los docentes:
#
# No hay conincidencias. :(

# %% [markdown]
# #### ***Conclusiones***
#
# No logré encontrar coincidencias importantes en relación a temáticas de inversión usando términos como "inversión", "inversiones", "mercado", "finanzas", por ende, opto por quedarme con las opciones disponibles de docentes que dentro de sus perfiles comentan que han trabajado con procesamiento de lenguaje natural, ya que esto será parte importante del desarrollo de toda la idea del proyecto de grado.
