# %% [markdown]
# ### Prueba Funcionamiento Notebooks en R

# %%
# Verificar versión y entorno
R.version.string

# Crear un gráfico de prueba
x <- seq(-10, 10, length.out = 100)
y <- sin(x)
plot(x, y, type = 'l', col = 'blue', main = 'Prueba R en Jupyter')
# Out:
# [1] "R version 4.6.1 (2026-06-24 ucrt)"
# Plot with title "Prueba R en Jupyter"
